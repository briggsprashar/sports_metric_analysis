# %% [markdown]
# # Part 3.1: Individual Athlete Timeline
# Analysis of PLAYER_741 and PLAYER_555 using selected performance metrics over time.

# %%
# --- Imports ---
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image

# --- Load Outputs ---
bw_741 = pd.read_csv("PLAYER_741/tables/best_worst_dates.csv")
reg_741 = pd.read_csv("PLAYER_741/tables/regression_stats.csv")

bw_555 = pd.read_csv("PLAYER_555/tables/best_worst_dates.csv")
reg_555 = pd.read_csv("PLAYER_555/tables/regression_stats.csv")

# %% [markdown]
# ## Best & Worst Performance Dates

# %%
bw_741
bw_555
# Out:
#                      metric            best_date   best_value  \
# 0            Distance_Total  2024-12-01 19:45:03  8259.075417
# 1            Jump Height(M)  2023-07-18 16:26:42     0.369600
# 2  Peak Propulsive Power(W)  2023-09-26 20:34:34  4318.514100
# 3        Peak Velocity(M/S)  2024-11-02 16:27:15     2.808500
# 4                 Speed_Max  2024-09-05 11:50:00     7.988296
#
#             worst_date  worst_value
# 0  2023-12-10 14:20:59     3.711586
# 1  2023-07-27 16:30:30     0.120900
# 2  2023-07-27 16:30:30  1896.458400
# 3  2023-07-27 16:30:30     1.768100
# 4  2024-11-21 14:00:00     0.493508

# %% [markdown]
# ## Regression Results

# %%
reg_741
reg_555
# Out:
#                      metric     slope   r_value   p_value   std_err
# 0            Distance_Total  0.376071  0.050702  0.348467  0.400563
# 1            Jump Height(M)  0.000011  0.063678  0.391781  0.000013
# 2  Peak Propulsive Power(W) -0.483159 -0.275457  0.000161  0.125332
# 3        Peak Velocity(M/S)  0.000045  0.062535  0.400354  0.000054
# 4                 Speed_Max  0.000764  0.121416  0.024110  0.000337

# %% [markdown]
# ## Inline Plots

# %%
Image("PLAYER_741/plots/Jump_Height(m).png")
Image("PLAYER_555/plots/Jump_Height(m).png")

# %% [markdown]
# ## Interpretation
# - PLAYER_741 shows [trend summary].
# - PLAYER_555 shows [trend summary].
# - Findings compared to literature review: [tie back to your research].
