# %%
# %pip install pandas numpy matplotlib seaborn jupyterlab
# Out:
# Requirement already satisfied: pandas in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (2.3.4)
# Requirement already satisfied: matplotlib in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (3.10.7)
# Requirement already satisfied: seaborn in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: jupyterlab in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (4.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyterlab) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyterlab) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyterlab) (7.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyterlab) (3.1.6)
# Requirement already satisfied: jupyter-core in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyterlab) (5.9.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyterlab) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyterlab) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyterlab) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyterlab) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyterlab) (80.9.0)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyterlab) (6.5.2)
# Requirement already satisfied: traitlets in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyterlab) (5.14.3)
# Requirement already satisfied: anyio in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab) (4.11.0)
# Requirement already satisfied: certifi in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab) (1.0.9)
# Requirement already satisfied: idna in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (8.6.3)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.23.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (3.0.2)
# Requirement already satisfied: pyzmq>=24 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.9.0)
# Requirement already satisfied: babel>=2.10 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (4.25.1)
# Requirement already satisfied: requests>=2.31 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (25.1.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (9.7.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (7.1.3)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jinja2>=3.0.3->jupyterlab) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (0.29.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyter-core->jupyterlab) (4.5.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (6.0.3)
# Requirement already satisfied: rfc3339-validator in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (4.14.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (6.3.0)
# Requirement already satisfied: defusedxml in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.21.2)
# Requirement already satisfied: six>=1.5 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.2.3)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (2.23)
# Requirement already satisfied: soupsieve>1.2 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (4.15.0)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\siddi\desktop\python\507_group_project_2025\.venv\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.4.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import f_oneway

# %%
#3.2 Individual Athlete Timeline

# %%
#3.2A Create box plots or violin plots comparing your selected metric(s) between teams

# Load and clean the dataset
df = pd.read_csv('raw/sixmetricsclass 3.csv')
df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')
df = df.dropna(subset=['value', 'groupteam', 'metric'])

# Get all unique metrics
all_metrics = df['metric'].unique()

# Plot each metric separately
for metric in all_metrics:
    metric_df = df[df['metric'] == metric]

    # Box Plot
    plt.figure(figsize=(12, 6))
    sns.boxplot(x='groupteam', y='value', data=metric_df)
    plt.title(f"Box Plot of {metric} by Team")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    # Violin Plot
    plt.figure(figsize=(12, 6))
    sns.violinplot(x='groupteam', y='value', data=metric_df, inner='quartile')
    plt.title(f"Violin Plot of {metric} by Team")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
